# %%
# Regression of one time series (ts) onto a field with lead lag years. field leads ts
# by '-ly' years. And do block bootstrap significant test 
# the output is for one lead-lag year: lead year '-ly'

length=6 # -5,....0 year
ly = 0
variable = 'transx'
block_length=2
n_resamples=1000
confidence_level=0.95

import pandas as pd
import xarray as xr
import numpy as np

# read data
data = xr.open_dataset('/work/uo1075/u241321/data/hfx_1970-2019_assi_dt.nc',decode_times=False)
ts = np.load("/work/uo1075/u241321/data/eemd_t310_assi_Norwegian.npy")[2,:]

corr      = xr.open_dataset("/work/uo1075/u241321/data/reg_"+variable+"_T_c2_44.nc")['__xarray_dataarray_variable__'] 


nyear=ts.size
var = np.mean(data['__xarray_dataarray_variable__'], axis=1)
var_1 = var.stack(spatial=('lat','lon')).dropna(dim="spatial") #time,space

y1 = var_1[length-1+ly:nyear+ly-1]
y2 = ts[length-1:nyear-1]

coef = corr[5+ly,:,:].stack(spatial=('lat','lon'))


# regression, center on 4-47, 44 year (start from 0)

# for m in range(0,field.shape[1],1):
#         coe[0,m] = regression(y[5:49], field[0:44,m])
#         coe[1,m] = regression(y[5:49], field[1:45,m])
#         coe[2,m] = regression(y[5:49], field[2:46,m])
#         coe[3,m] = regression(y[5:49], field[3:47,m])
#         coe[4,m] = regression(y[5:49], field[4:48,m])
#         coe[5,m] = regression(y[5:49], field[5:49,m])
 
# Due to technical issue, here use 44 years. Cut the last year.

#  LinearRegression

from sklearn.linear_model import LinearRegression
def regression(x,y):

    coef = LinearRegression(fit_intercept=True).fit(x.reshape(-1, 1), y.values.reshape(-1, 1)).coef_[0,0]
    

    return coef


# bootstrap

def _bootstrap_resample(sample1, sample2, block_length, n_resamples=None, random_state=None):
    """Bootstrap resample the sample."""
   
    np.random.shuffle(sample1.reshape((-1,block_length)))
    rng_state = np.random.get_state()
    np.random.set_state(rng_state)
    np.random.shuffle(sample2.values.reshape((-1,block_length)))
    
    # resamples = sample
    coef = regression(sample1, sample2)
    # bootstrap - each row is a random resample of original observations
    # i = rng_integers(random_state, 0, n, (n_resamples, n))

    # resamples = sample[..., i]
    return coef


def bootstrap(data1, data2, rawcoef, block_length, confidence_level, n_resamples,
              method, random_state=None):
 
    # the 1st dimension of data is time
    # confidence_level: 0.9, 0.95, 0.99...
    # n_resamples: 1000, 10000...
    # method: 'percentile', 'basic', 'bca'
    
    # the original Pearson correlation coefficients 
    coef_raw = rawcoef
 
    theta_hat_b = []

    batch_nominal = n_resamples

    for k in range(0, n_resamples):
        # batch_actual = min(batch_nominal, n_resamples-k)
        # Generate resamples
        resampled_coef_data = []
        # for sample in data:
        resample = _bootstrap_resample(data1, data2, block_length, 
                                           random_state=random_state)
        resampled_coef_data.append(resample)

        # Compute bootstrap distribution of Pearson correlation coefficients
        theta_hat_b.append(resampled_coef_data)
    theta_hat_b = np.concatenate(theta_hat_b, axis=-1)

    # Calculate percentile interval
    alpha = (1 - confidence_level)/2
    if method == 'bca':
        interval = _bca_interval(data, statistic, axis=-1, alpha=alpha,
                                 theta_hat_b=theta_hat_b, batch=batch)
        percentile_fun = _percentile_along_axis
    else:
        interval = alpha, 1-alpha

        def percentile_fun(a, q):
            return np.percentile(a=a, q=q, axis=-1)

    # Calculate confidence interval of statistic
    ci_l = percentile_fun(theta_hat_b, interval[0]*100)
    ci_u = percentile_fun(theta_hat_b, interval[1]*100)
    if method == 'basic':  # see [3]
        theta_hat = statistic(*data, axis=-1)
        ci_l, ci_u = 2*theta_hat - ci_u, 2*theta_hat - ci_l

      
    
    if coef_raw >= ci_u:
        sig = 1
    else:
        if coef_raw <= ci_l:
            sig = -1
        else:
            sig = 0
        
    return coef_raw ,sig

# apply to global filed

from multiprocessing import Pool
from itertools import product
from itertools import starmap

def boots_gridpoint(m):
    
    mode = bootstrap(
         y2, y1[:,m], coef[m], block_length=block_length, confidence_level=confidence_level, 
        n_resamples=n_resamples, method='percentile'
    )

    return mode


# pool = Pool()
# ! python --version

res = Pool().map(boots_gridpoint,np.arange(0,var.lat.size*var.lon.size,1))
re = np.array(res)

# output 
corr = re[:,0].reshape((var.lat.size, var.lon.size))
sig = re[:,1].reshape((var.lat.size, var.lon.size))

lat = data['lat']
lon = data['lon']
nlat = lat.size
nlon = lon.size

boot = xr.Dataset(data_vars={'lat': (["lat"], lat.data),
                              'lon':  (["lon"], lon.data),
                              'sig': (["lat", "lon"], sig),
                              'corr': (["lat", "lon"], corr),})
# corr = correlation["corr"]
boot.to_netcdf("/work/uo1075/u241321/data/boot_reg_"+variable+"_ly"+str(-ly)+"_block"+str(block_length)+"_new.nc")
# Out:
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/multiprocessing/pool.py", line 48, in mapstar
#     return list(map(*args))
#   File "/tmp/ipykernel_884698/1118131166.py", line 143, in boots_gridpoint
#     y2, y1[:,m], coef[m], block_length=block_length, confidence_level=confidence_level,
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataarray.py", line 817, in __getitem__
#     return self.isel(indexers=self._item_key_to_dict(key))
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataarray.py", line 1394, in isel
#     ds = self._to_temp_dataset()._isel_fancy(
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataset.py", line 2490, in _isel_fancy
#     new_var = var.isel(indexers=var_indexers)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/variable.py", line 1336, in isel
#     return self[key]
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/variable.py", line 880, in __getitem__
#     data = as_indexable(self._data)[indexer]
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/indexing.py", line 1603, in __getitem__
#     result = super().__getitem__(indexer)
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/indexing.py", line 1541, in __getitem__
#     result = self.array[key]
#   File "/sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/pandas/core/indexes/multi.py", line 2011, in __getitem__
#     if level_codes[key] == -1:
# IndexError: index 10514 is out of bounds for axis 0 with size 10500
# """
#
# The above exception was the direct cause of the following exception:
#
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 153
#     147     return mode
#     150 # pool = Pool()
#     151 # ! python --version
# --> 153 res = Pool().map(boots_gridpoint,np.arange(0,var.lat.size*var.lon.size,1))
#     154 re = np.array(res)
#     156 # output
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/multiprocessing/pool.py:367, in Pool.map(self, func, iterable, chunksize)
#     362 def map(self, func, iterable, chunksize=None):
#     363     '''
#     364     Apply `func` to each element in `iterable`, collecting the results
#     365     in a list that is returned.
#     366     '''
# --> 367     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/multiprocessing/pool.py:125, in worker()
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/multiprocessing/pool.py:48, in mapstar()
#      47 def mapstar(args):
# ---> 48     return list(map(*args))
#
# Cell In[1], line 143, in boots_gridpoint()
#     140 def boots_gridpoint(m):
#     142     mode = bootstrap(
# --> 143          y2, y1[:,m], coef[m], block_length=block_length, confidence_level=confidence_level,
#     144         n_resamples=n_resamples, method='percentile'
#     145     )
#     147     return mode
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataarray.py:817, in __getitem__()
#     814     return self._getitem_coord(key)
#     815 else:
#     816     # xarray-style array indexing
# --> 817     return self.isel(indexers=self._item_key_to_dict(key))
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataarray.py:1394, in isel()
#    1391 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "isel")
#    1393 if any(is_fancy_indexer(idx) for idx in indexers.values()):
# -> 1394     ds = self._to_temp_dataset()._isel_fancy(
#    1395         indexers, drop=drop, missing_dims=missing_dims
#    1396     )
#    1397     return self._from_temp_dataset(ds)
#    1399 # Much faster algorithm for when all indexers are ints, slices, one-dimensional
#    1400 # lists, or zero or one-dimensional np.ndarray's
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/dataset.py:2490, in _isel_fancy()
#    2486 var_indexers = {
#    2487     k: v for k, v in valid_indexers.items() if k in var.dims
#    2488 }
#    2489 if var_indexers:
# -> 2490     new_var = var.isel(indexers=var_indexers)
#    2491     # drop scalar coordinates
#    2492     # https://github.com/pydata/xarray/issues/6554
#    2493     if name in self.coords and drop and new_var.ndim == 0:
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/variable.py:1336, in isel()
#    1333 indexers = drop_dims_from_indexers(indexers, self.dims, missing_dims)
#    1335 key = tuple(indexers.get(dim, slice(None)) for dim in self.dims)
# -> 1336 return self[key]
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/variable.py:880, in __getitem__()
#     867 """Return a new Variable object whose contents are consistent with
#     868 getting the provided key from the underlying data.
#     869
#    (...)
#     877 array `x.values` directly.
#     878 """
#     879 dims, indexer, new_order = self._broadcast_indexes(key)
# --> 880 data = as_indexable(self._data)[indexer]
#     881 if new_order:
#     882     data = np.moveaxis(data, range(len(new_order)), new_order)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/indexing.py:1603, in __getitem__()
#    1602 def __getitem__(self, indexer):
# -> 1603     result = super().__getitem__(indexer)
#    1604     if isinstance(result, type(self)):
#    1605         result.level = self.level
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/xarray/core/indexing.py:1541, in __getitem__()
#    1538 if getattr(key, "ndim", 0) > 1:  # Return np-array if multidimensional
#    1539     return NumpyIndexingAdapter(np.asarray(self))[indexer]
# -> 1541 result = self.array[key]
#    1543 if isinstance(result, pd.Index):
#    1544     return type(self)(result, dtype=self.dtype)
#
# File /sw/spack-levante/mambaforge-22.9.0-2-Linux-x86_64-kptncg/lib/python3.10/site-packages/pandas/core/indexes/multi.py:2011, in __getitem__()
#    2009 retval = []
#    2010 for lev, level_codes in zip(self.levels, self.codes):
# -> 2011     if level_codes[key] == -1:
#    2012         retval.append(np.nan)
#    2013     else:
#
# IndexError: index 10514 is out of bounds for axis 0 with size 10500
