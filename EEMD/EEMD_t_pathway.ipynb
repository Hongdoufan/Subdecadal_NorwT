# %%
import xarray as xr
import numpy as np
import glob
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import matplotlib.ticker as mticker
import cartopy.feature as cfeature
import cartopy.io.shapereader as shpreader
from cartopy.mpl.gridliner import LONGITUDE_FORMATTER, LATITUDE_FORMATTER
from xarray import DataArray
import pandas as pd
from PyEMD import EEMD
import pylab as plt

# %%
mode = 4+1 # mode(input, c1-c4)
station = 10 # 10 new stations selected by ssh
time = 50
ly = 10
assi_eemd_9 = np.zeros((5,station,50)) # mode(input, c1-c4), station, time
hind_eemd_9 = np.zeros((5,station,50,ly)) # mode(input, c1-c4), station, time, lead year

# %%
data       = xr.open_dataset("/work/uo1075/u241321/data/temperature_1965-2019_assi_5000.nc") 
data_h       = xr.open_dataset("/work/uo1075/u241321/data/u241321/data_cdo/thetao_ly_1969-2019_hindcast.nc",decode_times=False) 

blat= [55, 50, 52.5, 55, 58, 61, 58.5, 63.5, 68.5, 76.5]
blon= [-51, -48, -34.5, -24.5, -16, -2.5, 3.5, 3.5, 11.5, 10.5]
boxsize=5


lat_min, lat_max = (blat[0]-boxsize/2.,blat[0]+boxsize/2.) # sation 1   size 5*5 degree box
lon_min, lon_max = (blon[0]-boxsize/2.,blon[0]+boxsize/2.)

# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,0,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var22 = data_h['thetao']
sst_h = np.mean(np.mean(var22, axis=1)[:,:,0:15,:,:],2)
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,0,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[1]-boxsize/2.,blat[1]+boxsize/2.) # sation 2   size 5*5 degree box
lon_min, lon_max = (blon[1]-boxsize/2.,blon[1]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,1,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast

var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,1,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[2]-boxsize/2.,blat[2]+boxsize/2.) # sation 3   size 5*5 degree box
lon_min, lon_max = (blon[2]-boxsize/2.,blon[2]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,2,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,2,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[3]-boxsize/2.,blat[3]+boxsize/2.) # sation 4   size 5*5 degree box
lon_min, lon_max = (blon[3]-boxsize/2.,blon[3]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,3,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,3,:,:] = air_weighted1.mean(("lon", "lat"))

lat_min, lat_max = (blat[4]-boxsize/2.,blat[4]+boxsize/2.) # sation 5   size 5*5 degree box
lon_min, lon_max = (blon[4]-boxsize/2.,blon[4]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,4,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,4,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[5]-boxsize/2.,blat[5]+boxsize/2.) # sation 6   size 5*5 degree box
lon_min, lon_max = (blon[5]-boxsize/2.,blon[5]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,5,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,5,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[6]-boxsize/2.,blat[6]+boxsize/2.) # sation 7   size 5*5 degree box
lon_min, lon_max = (blon[6]-boxsize/2.,blon[6]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,6,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,6,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[7]-boxsize/2.,blat[7]+boxsize/2.) # sation 8   size 5*5 degree box
lon_min, lon_max = (blon[7]-boxsize/2.,blon[7]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,7,:] = air_weighted.mean(("lon", "lat"))

# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,7,:,:] = air_weighted1.mean(("lon", "lat"))


lat_min, lat_max = (blat[8]-boxsize/2.,blat[8]+boxsize/2.) # sation 9   size 5*5 degree box
lon_min, lon_max = (blon[8]-boxsize/2.,blon[8]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,8,:] = air_weighted.mean(("lon", "lat"))

lat_min, lat_max = (blat[9]-boxsize/2.,blat[9]+boxsize/2.) # sation 10   size 5*5 degree box
lon_min, lon_max = (blon[9]-boxsize/2.,blon[9]+boxsize/2.)
# weight average for assi
var11 = data['thetao'].sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
var1 = np.mean(np.mean(var11, axis=1)[5::,0:15,:,:],1)

weights = np.cos(np.deg2rad(var1.lat))
weights.name = "weights"
air_weighted = var1.weighted(weights)
assi_eemd_9[0,9,:] = air_weighted.mean(("lon", "lat"))


# weight average for hindcast
var2 = sst_h.sel(lat=slice(lat_min, lat_max), lon=slice(lon_min, lon_max))
air_weighted1 = var2.weighted(weights)
hind_eemd_9[0,9,:,:] = air_weighted1.mean(("lon", "lat"))

# %%
# EEMD options
max_imf=3
# Prepare and run EEMD
eemd = EEMD(trials=10000, FIXE_H=10, DTYPE=np.float16, noise_width=0.2)   #max_imfs=10)
eemd.noise_seed(6021)

t = np.arange(1970,2020,1)

# %%
# Execute EEMD on ASSIM
for n in range(0,station,1):                       
        # for i in range(0,ly,1):                       
            # hind_eemd_9[1::,n,:,i] = eemd.eemd(hind_eemd_9[0,n,:,i], t, max_imf)  
        assi_eemd_9[1::,n,:] = eemd.eemd(assi_eemd_9[0,n,:], t, max_imf)

# %%
# np.save("/work/uo1075/u241321/data/hind_eemd_t_10", hind_eemd_9)
np.save("/work/uo1075/u241321/data/assi_eemd_t_10", assi_eemd_9)

# %%
assi_eemd_9
# Out:
# array([[[ 0.07565207, -0.14158238, -0.78269485, ..., -0.05146398,
#           0.0261394 ,  0.23415221],
#         [ 0.34950155, -0.11782476, -1.09382926, ...,  0.28441604,
#           0.42723559,  0.40044337],
#         [ 0.25215788,  0.00363713, -0.83881948, ..., -0.21814372,
#          -0.4606141 , -0.16266265],
#         ...,
#         [-0.54358981, -0.20402042,  0.08277948, ...,  0.86804784,
#           0.32699289,  0.54919128],
#         [-0.44949879, -0.36918805,  0.10067639, ...,  0.85664992,
#           0.57758439,  0.3680453 ],
#         [-0.50954045, -0.95877864, -1.00401278, ...,  1.46309482,
#           0.8621573 ,  0.8616869 ]],
#
#        [[ 0.29049644,  0.18850915, -0.33371916, ..., -0.01231544,
#          -0.02683275,  0.11621201],
#         [ 0.55042729,  0.27674175, -0.43351008, ...,  0.04561633,
#           0.07077853,  0.04763724],
#         [ 0.38726668,  0.23619726, -0.29045369, ...,  0.28293764,
#          -0.15149731,  0.12851372],
#         ...,
# ...
